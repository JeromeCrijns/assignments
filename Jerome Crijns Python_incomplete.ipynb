# %%
immo = hond
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-83e49fa0d72c> in <module>()
# ----> 1 immo = hond
#
# NameError: name 'hond' is not defined

# %%
hond = 2

# %%
2
# Out:
# 2

# %%
hond
# Out:
# 2

# %%
immo
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-22ded4329f2c> in <module>()
# ----> 1 immo
#
# NameError: name 'immo' is not defined

# %%
variable_immo = hond

# %%
variable_immo
# Out:
# 2

# %%
"immo"
# Out:
# 'immo'

# %%
# groetjes

# %%
# groetjes

# %%
import matplotlib.pyplot as plt

# %%
range_x = np.arange(-1,1,0.1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-8bcbcb4f9e19> in <module>()
# ----> 1 range_x = np.arange(-1,1,0.1)
#
# NameError: name 'np' is not defined

# %%
import numpy as np

# %%
range_x = np.arange(-1,1,0.1)

# %%
import numpy as np

# %%
import matplotlib.pylot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-16-c988897a33fb> in <module>()
# ----> 1 import matplotlib.pylot as plt
#
# ImportError: No module named 'matplotlib.pylot'

# %%
range_x = np.arange(-1,1,0.1)

# %%
import matplotlib.pyplot as plt

# %%
range_x = np.arange(-1,1,0.1)

# %%
range_x = np.arange(-1,1.1,0.1)
